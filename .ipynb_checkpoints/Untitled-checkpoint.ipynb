# %%
library(ggplot2)

# %%
x = seq(from = 1, to = 10, by = 0.1)
df = data.frame(x = x,
    y = sin(x)
    )

# %%
g <- ggplot(data = df, aes(x = x, y = y)) +
geom_line()

# %%
print(g)
# Out:
# plot without title
